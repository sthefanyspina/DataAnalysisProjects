# %%
import pandas as pd

# %%
df = pd.read_csv('PlayerStatistics.csv')
# Out:
# C:\Users\sthefany.bspina\AppData\Local\Temp\ipykernel_59684\2152893101.py:1: DtypeWarning: Columns (10,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('PlayerStatistics.csv')

# %%
df.head()
# Out:
#   firstName lastName  personId    gameId             gameDate playerteamCity  \
# 0      Mike   Conley    201144  42400231  2025-05-06 21:30:00      Minnesota
# 1   Stephen    Curry    201939  42400231  2025-05-06 21:30:00   Golden State
# 2     Jimmy   Butler    202710  42400231  2025-05-06 21:30:00   Golden State
# 3  Draymond    Green    203110  42400231  2025-05-06 21:30:00   Golden State
# 4      Rudy   Gobert    203497  42400231  2025-05-06 21:30:00      Minnesota
#
#   playerteamName opponentteamCity opponentteamName  gameType  ...  \
# 0   Timberwolves     Golden State         Warriors  Playoffs  ...
# 1       Warriors        Minnesota     Timberwolves  Playoffs  ...
# 2       Warriors        Minnesota     Timberwolves  Playoffs  ...
# 3       Warriors        Minnesota     Timberwolves  Playoffs  ...
# 4   Timberwolves     Golden State         Warriors  Playoffs  ...
#
#   threePointersPercentage freeThrowsAttempted  freeThrowsMade  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1626393 entries, 0 to 1626392
# Data columns (total 35 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   firstName                1626393 non-null  object
#  1   lastName                 1626393 non-null  object
#  2   personId                 1626393 non-null  int64
#  3   gameId                   1626393 non-null  int64
#  4   gameDate                 1626393 non-null  object
#  5   playerteamCity           1626393 non-null  object
#  6   playerteamName           1626393 non-null  object
#  7   opponentteamCity         1626393 non-null  object
#  8   opponentteamName         1626393 non-null  object
#  9   gameType                 1626393 non-null  object
#  10  gameLabel                89538 non-null    object
#  11  gameSubLabel             3342 non-null     object
#  12  seriesGameNumber         134003 non-null   float64
# ...

# %%
df.describe()
# Out:
#            personId        gameId  seriesGameNumber           win  \
# count  1.626393e+06  1.626393e+06     134003.000000  1.626393e+06
# mean   2.703388e+05  2.540686e+07          2.377536  4.996781e-01
# std    4.646136e+06  6.499494e+06          2.039595  5.000001e-01
# min    2.000000e+00  1.030000e+07          0.000000  0.000000e+00
# 25%    1.733000e+03  2.120025e+07          0.000000  0.000000e+00
# 50%    7.705700e+04  2.510020e+07          2.000000  0.000000e+00
# 75%    2.015880e+05  2.860068e+07          4.000000  1.000000e+00
# max    1.962938e+09  6.240000e+07          7.000000  1.000000e+00
#
#                home    numMinutes        points       assists        blocks  \
# count  1.626393e+06  1.465079e+06  1.625174e+06  1.625174e+06  1.625174e+06
# mean   5.005223e-01  2.178817e+01  9.197767e+00  1.960207e+00  3.686055e-01
# std    4.999999e-01  1.278417e+01  8.519524e+00  2.545802e+00  8.332762e-01
# ...

# %%
print(df.isnull().sum())
# Out:
# firstName                        0
# lastName                         0
# personId                         0
# gameId                           0
# gameDate                         0
# playerteamCity                   0
# playerteamName                   0
# opponentteamCity                 0
# opponentteamName                 0
# gameType                         0
# gameLabel                  1536855
# gameSubLabel               1623051
# seriesGameNumber           1492390
# win                              0
# home                             0
# numMinutes                  161314
# points                        1219
# assists                       1219
# blocks                        1219
# steals                        1219
# fieldGoalsAttempted           1219
# fieldGoalsMade                1219
# fieldGoalsPercentage          1219
# threePointersAttempted        1219
# threePointersMade             1219
# threePointersPercentage       1219
# freeThrowsAttempted           1219
# ...

# %%
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2589 entries, 0 to 36478
# Data columns (total 35 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   firstName                2589 non-null   object
#  1   lastName                 2589 non-null   object
#  2   personId                 2589 non-null   int64
#  3   gameId                   2589 non-null   int64
#  4   gameDate                 2589 non-null   object
#  5   playerteamCity           2589 non-null   object
#  6   playerteamName           2589 non-null   object
#  7   opponentteamCity         2589 non-null   object
#  8   opponentteamName         2589 non-null   object
#  9   gameType                 2589 non-null   object
#  10  gameLabel                2589 non-null   object
#  11  gameSubLabel             2589 non-null   object
#  12  seriesGameNumber         2589 non-null   float64
#  13  win                      2589 non-null   int64
# ...

# %%
print(df.dtypes)
# Out:
# firstName                   object
# lastName                    object
# personId                     int64
# gameId                       int64
# gameDate                    object
# playerteamCity              object
# playerteamName              object
# opponentteamCity            object
# opponentteamName            object
# gameType                    object
# gameLabel                   object
# gameSubLabel                object
# seriesGameNumber           float64
# win                          int64
# home                         int64
# numMinutes                 float64
# points                     float64
# assists                    float64
# blocks                     float64
# steals                     float64
# fieldGoalsAttempted        float64
# fieldGoalsMade             float64
# fieldGoalsPercentage       float64
# threePointersAttempted     float64
# threePointersMade          float64
# threePointersPercentage    float64
# freeThrowsAttempted        float64
# ...

# %%
df = df.astype({"seriesGameNumber": 'int64', "numMinutes": 'int64', "points": 'int64', "assists": 'int64',
               "blocks": 'int64',"steals": 'int64',"fieldGoalsAttempted": 'int64',"fieldGoalsMade": 'int64',
               "fieldGoalsPercentage": 'int64',"threePointersAttempted": 'int64',"threePointersMade": 'int64',"threePointersPercentage": 'int64',
               "freeThrowsAttempted": 'int64',"freeThrowsMade": 'int64',"freeThrowsPercentage": 'int64',"reboundsDefensive": 'int64',
               "reboundsOffensive": 'int64',"reboundsTotal": 'int64',"foulsPersonal": 'int64',"turnovers": 'int64', "plusMinusPoints": 'int64'})

# %%
print(df.dtypes)
# Out:
# firstName                  object
# lastName                   object
# personId                    int64
# gameId                      int64
# gameDate                   object
# playerteamCity             object
# playerteamName             object
# opponentteamCity           object
# opponentteamName           object
# gameType                   object
# gameLabel                  object
# gameSubLabel               object
# seriesGameNumber            int64
# win                         int64
# home                        int64
# numMinutes                  int64
# points                      int64
# assists                     int64
# blocks                      int64
# steals                      int64
# fieldGoalsAttempted         int64
# fieldGoalsMade              int64
# fieldGoalsPercentage        int64
# threePointersAttempted      int64
# threePointersMade           int64
# threePointersPercentage     int64
# freeThrowsAttempted         int64
# ...

# %%
df.to_csv("PlayerStatistics2.csv", index=False)
