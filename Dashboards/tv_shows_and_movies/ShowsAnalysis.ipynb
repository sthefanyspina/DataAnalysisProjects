# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('shows.csv')

# %%
df.head()
# Out:
#    rank    show_id             title  year  \
# 0     1  tt5491994   Planet Earth II  2016
# 1     2  tt0903747      Breaking Bad  2008
# 2     3  tt0795176      Planet Earth  2006
# 3     4  tt0185906  Band of Brothers  2001
# 4     5  tt7366338         Chernobyl  2019
#
#                                    link imbd_votes  imbd_rating certificate  \
# 0  https://www.imdb.com/title/tt5491994    145,597          9.5        TV-G
# 1  https://www.imdb.com/title/tt0903747  1,881,190          9.5       TV-MA
# 2  https://www.imdb.com/title/tt0795176    210,164          9.4       TV-PG
# 3  https://www.imdb.com/title/tt0185906    469,081          9.4       TV-MA
# 4  https://www.imdb.com/title/tt7366338    751,884          9.4       TV-MA
#
#   duration                   genre  ...  \
# 0   4h 58m             Documentary  ...
# 1      49m    Crime,Drama,Thriller  ...
# 2   8h 58m             Documentary  ...
# 3   9h 54m       Drama,History,War  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 22 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   rank            250 non-null    int64
#  1   show_id         250 non-null    object
#  2   title           250 non-null    object
#  3   year            250 non-null    int64
#  4   link            250 non-null    object
#  5   imbd_votes      250 non-null    object
#  6   imbd_rating     250 non-null    float64
#  7   certificate     246 non-null    object
#  8   duration        249 non-null    object
#  9   genre           250 non-null    object
#  10  cast_id         250 non-null    object
#  11  cast_name       250 non-null    object
#  12  director_id     250 non-null    object
#  13  director_name   250 non-null    object
#  14  writer_id       250 non-null    object
#  15  writer_name     250 non-null    object
#  16  storyline       250 non-null    object
# ...

# %%
df.describe()
# Out:
#              rank         year  imbd_rating
# count  250.000000   250.000000   250.000000
# mean   125.500000  2006.844000     8.765600
# std     72.312977    12.511668     0.233398
# min      1.000000  1955.000000     8.500000
# 25%     63.250000  2001.000000     8.600000
# 50%    125.500000  2010.000000     8.700000
# 75%    187.750000  2016.000000     8.900000
# max    250.000000  2022.000000     9.600000

# %%
print(df.isnull().sum())
# Out:
# rank              0
# show_id           0
# title             0
# year              0
# link              0
# imbd_votes        0
# imbd_rating       0
# certificate       4
# duration          1
# genre             0
# cast_id           0
# cast_name         0
# director_id       0
# director_name     0
# writer_id         0
# writer_name       0
# storyline         0
# user_id           0
# user_name         0
# review_id         0
# review_title      0
# review_content    0
# dtype: int64

# %%
df.replace('', np.nan, inplace=True)

# %%
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 245 entries, 0 to 249
# Data columns (total 22 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   rank            245 non-null    int64
#  1   show_id         245 non-null    object
#  2   title           245 non-null    object
#  3   year            245 non-null    int64
#  4   link            245 non-null    object
#  5   imbd_votes      245 non-null    object
#  6   imbd_rating     245 non-null    float64
#  7   certificate     245 non-null    object
#  8   duration        245 non-null    object
#  9   genre           245 non-null    object
#  10  cast_id         245 non-null    object
#  11  cast_name       245 non-null    object
#  12  director_id     245 non-null    object
#  13  director_name   245 non-null    object
#  14  writer_id       245 non-null    object
#  15  writer_name     245 non-null    object
#  16  storyline       245 non-null    object
# ...

# %%
print(df.dtypes)
# Out:
# rank                int64
# show_id            object
# title              object
# year                int64
# link               object
# imbd_votes         object
# imbd_rating       float64
# certificate        object
# duration           object
# genre              object
# cast_id            object
# cast_name          object
# director_id        object
# director_name      object
# writer_id          object
# writer_name        object
# storyline          object
# user_id            object
# user_name          object
# review_id          object
# review_title       object
# review_content     object
# dtype: object

# %%
df.to_csv("shows2.csv", index=False)
