# %%
import pandas as pd

# %%
df = pd.read_csv('players.csv')

# %%
df.head()
# Out:
#           id   birthdate              birthplace  career_ast  career_fg  \
# 0  abdelal01  1968-06-24            Cairo, Egypt         0.3       50.2
# 1  abdulza01  1946-04-07      Brooklyn, New York         1.2       42.8
# 2  abdulka01  1947-04-16      New York, New York         3.6       55.9
# 3  abdulma02  1969-03-09   Gulfport, Mississippi         3.5       44.2
# 4  abdulta01  1974-11-03  Maisons Alfort, France         1.1       41.7
#
#    career_fg3  career_ft  career_g  career_per  career_pts  ...    draft_pick  \
# 0         0.0       70.1       256        13.0         5.7  ...  25th overall
# 1         NaN       72.8       505        15.1         9.0  ...   5th overall
# 2         5.6       72.1      1560        24.6        24.6  ...   1st overall
# 3        35.4       90.5       586        15.4        14.6  ...   3rd overall
# 4        23.7       70.3       236        11.4         7.8  ...  11th overall
#
#    draft_round              draft_team draft_year height  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4685 entries, 0 to 4684
# Data columns (total 24 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           4685 non-null   object
#  1   birthdate    4657 non-null   object
#  2   birthplace   4185 non-null   object
#  3   career_ast   4685 non-null   float64
#  4   career_fg    4657 non-null   float64
#  5   career_fg3   3062 non-null   float64
#  6   career_ft    4481 non-null   float64
#  7   career_g     4685 non-null   int64
#  8   career_per   4335 non-null   float64
#  9   career_pts   4685 non-null   float64
#  10  career_trb   4393 non-null   float64
#  11  career_ws    4683 non-null   float64
#  12  career_efg   3535 non-null   float64
#  13  college      4372 non-null   object
#  14  draft_pick   3369 non-null   object
#  15  draft_round  3507 non-null   object
#  16  draft_team   3507 non-null   object
#  17  draft_year   3306 non-null   object
# ...

# %%
df.describe()
# Out:
#         career_ast    career_fg   career_fg3    career_ft     career_g  \
# count  4685.000000  4657.000000  3062.000000  4481.000000  4685.000000
# mean      1.420064    40.795061    23.911659    69.614483   274.284525
# std       1.356122    10.483566    15.994693    14.097617   311.116918
# min       0.000000     0.000000     0.000000     0.000000     1.000000
# 25%       0.500000    36.600000    13.300000    63.200000    33.000000
# 50%       1.000000    42.300000    27.300000    71.600000   133.000000
# 75%       1.900000    46.400000    34.200000    78.200000   456.000000
# max      11.200000   100.000000   100.000000   100.000000  1611.000000
#
#         career_per   career_pts   career_trb    career_ws   career_efg
# count  4335.000000  4685.000000  4393.000000  4683.000000  3535.000000
# mean     11.260000     6.425208     3.058866    13.870340    45.212588
# std       6.468858     4.738534     2.323081    26.231012    10.002043
# ...

# %%
print(df.isnull().sum())
# Out:
# id                0
# birthdate        28
# birthplace      500
# career_ast        0
# career_fg        28
# career_fg3     1623
# career_ft       204
# career_g          0
# career_per      350
# career_pts        0
# career_trb      292
# career_ws         2
# career_efg     1150
# college         313
# draft_pick     1316
# draft_round    1178
# draft_team     1178
# draft_year     1379
# height            0
# highschool      660
# name              0
# position          0
# shoots            1
# weight            5
# dtype: int64

# %%
df_cleaned = df.dropna()

# %%
print(df_cleaned)
# Out:
#              id   birthdate              birthplace  career_ast  career_fg  \
# 0     abdelal01  1968-06-24            Cairo, Egypt         0.3       50.2
# 2     abdulka01  1947-04-16      New York, New York         3.6       55.9
# 3     abdulma02  1969-03-09   Gulfport, Mississippi         3.5       44.2
# 4     abdulta01  1974-11-03  Maisons Alfort, France         1.1       41.7
# 5     abdursh01  1976-12-11       Marietta, Georgia         2.5       47.2
# ...         ...         ...                     ...         ...        ...
# 4661  youngth01  1988-06-21  New Orleans, Louisiana         1.7       50.1
# 4663  youngtr01  1998-09-19          Lubbock, Texas         8.1       41.8
# 4667  zelleco01  1992-10-05     Washington, Indiana         1.4       51.1
# 4672  zellety01  1990-01-17     Visalia, California         0.9       50.9
# 4676  zidekge01  1973-08-02    Zlin, Czech Republic         0.2       40.8
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2101 entries, 0 to 4676
# Data columns (total 24 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           2101 non-null   object
#  1   birthdate    2101 non-null   object
#  2   birthplace   2101 non-null   object
#  3   career_ast   2101 non-null   float64
#  4   career_fg    2101 non-null   float64
#  5   career_fg3   2101 non-null   float64
#  6   career_ft    2101 non-null   float64
#  7   career_g     2101 non-null   int64
#  8   career_per   2101 non-null   float64
#  9   career_pts   2101 non-null   float64
#  10  career_trb   2101 non-null   float64
#  11  career_ws    2101 non-null   float64
#  12  career_efg   2101 non-null   float64
#  13  college      2101 non-null   object
#  14  draft_pick   2101 non-null   object
#  15  draft_round  2101 non-null   object
#  16  draft_team   2101 non-null   object
#  17  draft_year   2101 non-null   object
# ...

# %%
print(df.dtypes)
# Out:
# id              object
# birthdate       object
# birthplace      object
# career_ast     float64
# career_fg      float64
# career_fg3     float64
# career_ft      float64
# career_g         int64
# career_per     float64
# career_pts     float64
# career_trb     float64
# career_ws      float64
# career_efg     float64
# college         object
# draft_pick      object
# draft_round     object
# draft_team      object
# draft_year      object
# height          object
# highschool      object
# name            object
# position        object
# shoots          object
# weight          object
# dtype: object

# %%
df.to_csv("players2.csv", index=False)
